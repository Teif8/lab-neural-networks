# %% [markdown]
# # Challenge 1 - Tic Tac Toe
#
# In this lab you will perform deep learning analysis on a dataset of playing [Tic Tac Toe](https://en.wikipedia.org/wiki/Tic-tac-toe).
#
# There are 9 grids in Tic Tac Toe that are coded as the following picture shows:
#
# ![Tic Tac Toe Grids](tttboard.jpg)
#
# In the first 9 columns of the dataset you can find which marks (`x` or `o`) exist in the grids. If there is no mark in a certain grid, it is labeled as `b`. The last column is `class` which tells you whether Player X (who always moves first in Tic Tac Toe) wins in this configuration. Note that when `class` has the value `False`, it means either Player O wins the game or it ends up as a draw.

# %% [markdown]
# Follow the steps suggested below to conduct a neural network analysis using Tensorflow and Keras. You will build a deep learning model to predict whether Player X wins the game or not.
#
# ## Step 1: Data Engineering
#
# This dataset is almost in the ready-to-use state so you do not need to worry about missing values and so on. Still, some simple data engineering is needed.
#
# 1. Read `tic-tac-toe.csv` into a dataframe.
# 1. Inspect the dataset. Determine if the dataset is reliable by eyeballing the data.
# 1. Convert the categorical values to numeric in all columns.
# 1. Separate the inputs and output.
# 1. Normalize the input data.

# %%
# your code here
import pandas as pd
df = pd.read_csv("tic-tac-toe.csv")

# %%
print(df.head())      # Display the first few rows
print(df.info())      # Get dataset summary
print(df.describe())  # Check basic statistics
print(df.nunique())   # Check unique values per column
# Out:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TL      958 non-null    object
#  1   TM      958 non-null    object
#  2   TR      958 non-null    object
#  3   ML      958 non-null    object
#  4   MM      958 non-null    object
#  5   MR      958 non-null    object
#  6   BL      958 non-null    object
#  7   BM      958 non-null    object
#  8   BR      958 non-null    object
#  9   class   958 non-null    bool
# dtypes: bool(1), object(9)
# memory usage: 68.4+ KB
# None
#          TL   TM   TR   ML   MM   MR   BL   BM   BR class
# count   958  958  958  958  958  958  958  958  958   958
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df = df.apply(encoder.fit_transform)

# %%
X = df.iloc[:, :-1]  # Input features (all columns except last)
y = df.iloc[:, -1]   # Target variable (last column)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# %% [markdown]
# ## Step 2: Build Neural Network
#
# To build the neural network, you can refer to your own codes you wrote while following the [Deep Learning with Python, TensorFlow, and Keras tutorial](https://www.youtube.com/watch?v=wQ8BIBpya2k) in the lesson. It's pretty similar to what you will be doing in this lab.
#
# 1. Split the training and test data.
# 1. Create a `Sequential` model.
# 1. Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.
# 1. Compile the model using `adam` as the optimizer and `sparse_categorical_crossentropy` as the loss function. For metrics, use `accuracy` for now.
# 1. Fit the training data.
# 1. Evaluate your neural network model with the test data.
# 1. Save your model as `tic-tac-toe.model`.

# %%
# your code here
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
## Add layers to the model 

# Input layer (assuming X has 9 features)
model.add(Dense(16, activation='relu', input_shape=(X_train.shape[1],)))

# Hidden layers
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))

# Output layer (Softmax for multi-class classification)
model.add(Dense(2, activation='softmax'))  # 2 classes (win/loss)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1)
# Out:
# Epoch 1/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8638 - loss: 0.3074 - val_accuracy: 0.8571 - val_loss: 0.4551
# Epoch 2/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step - accuracy: 0.8910 - loss: 0.3053 - val_accuracy: 0.8571 - val_loss: 0.4634
# Epoch 3/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.8558 - loss: 0.3168 - val_accuracy: 0.8571 - val_loss: 0.4566
# Epoch 4/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step - accuracy: 0.8954 - loss: 0.2911 - val_accuracy: 0.8442 - val_loss: 0.4609
# Epoch 5/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - accuracy: 0.8672 - loss: 0.3168 - val_accuracy: 0.8442 - val_loss: 0.4702
# Epoch 6/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - accuracy: 0.8821 - loss: 0.3063 - val_accuracy: 0.8312 - val_loss: 0.4676
# Epoch 7/50
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - accuracy: 0.8832 - loss: 0.2839 - val_accuracy: 0.8182 - val_loss: 0.4854
# Epoch 8/50
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8301 - loss: 0.4705
# Test Accuracy: 0.8125

# %%
model.save("tic-tac-toe.keras")

# %% [markdown]
# ## Step 3: Make Predictions
#
# Now load your saved model and use it to make predictions on a few random rows in the test dataset. Check if the predictions are correct.

# %%
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model("tic-tac-toe.keras")  # Change to .h5 if needed

# %%
import numpy as np

# Select 5 random test indices
random_indices = np.random.choice(len(X_test), 5, replace=False)

# Get corresponding input features and actual labels
X_sample = X_test[random_indices]
y_sample = y_test.iloc[random_indices]

# %%
predictions = model.predict(X_sample)
predicted_labels = np.argmax(predictions, axis=1)  # Get class with highest probability
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
print(model.predict(X_sample))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# [[0.16385    0.83615005]
#  [0.12741604 0.8725839 ]
#  [0.9655318  0.03446818]
#  [0.00348025 0.9965198 ]
#  [0.03910119 0.9608988 ]]

# %%
print("Actual Labels:   ", y_sample.values)
print("Predicted Labels:", predicted_labels)
# Out:
# Actual Labels:    [0 1 0 1 1]
# Predicted Labels: [1 1 0 1 1]

# %%
print(predictions)  # Prints probabilities for each class
# Out:
# [[0.16385    0.83615005]
#  [0.12741604 0.8725839 ]
#  [0.9655318  0.03446818]
#  [0.00348025 0.9965198 ]
#  [0.03910119 0.9608988 ]]

# %% [markdown]
# ## Step 4: Improve Your Model
#
# Did your model achieve low loss (<0.1) and high accuracy (>0.95)? If not, try to improve your model.
#
# But how? There are so many things you can play with in Tensorflow and in the next challenge you'll learn about these things. But in this challenge, let's just do a few things to see if they will help.
#
# * Add more layers to your model. If the data are complex you need more layers. But don't use more layers than you need. If adding more layers does not improve the model performance you don't need additional layers.
# * Adjust the learning rate when you compile the model. This means you will create a custom `tf.keras.optimizers.Adam` instance where you specify the learning rate you want. Then pass the instance to `model.compile` as the optimizer.
#     * `tf.keras.optimizers.Adam` [reference](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam).
#     * Don't worry if you don't understand what the learning rate does. You'll learn about it in the next challenge.
# * Adjust the number of epochs when you fit the training data to the model. Your model performance continues to improve as you train more epochs. But eventually it will reach the ceiling and the performance will stay the same.

# %%
from imblearn.over_sampling import RandomOverSampler

# Apply oversampling
oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X_train, y_train)

# %%
class_weights = {0: 2.0, 1: 1.0}  # Give more importance to "0"

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout

model = Sequential([
    Dense(32, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(2, activation='softmax')  # Output for 2 classes
])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
model.fit(X_train, y_train, epochs=100, batch_size=16, class_weight=class_weights)
# Out:
# Epoch 1/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - accuracy: 0.4280 - loss: 0.9223
# Epoch 2/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - accuracy: 0.5295 - loss: 0.9062
# Epoch 3/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - accuracy: 0.5545 - loss: 0.9064
# Epoch 4/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - accuracy: 0.5472 - loss: 0.9093
# Epoch 5/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - accuracy: 0.5639 - loss: 0.9101
# Epoch 6/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - accuracy: 0.6863 - loss: 0.8657
# Epoch 7/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - accuracy: 0.5580 - loss: 0.8846
# Epoch 8/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - accuracy: 0.7003 - loss: 0.8294
# Epoch 9/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - accuracy: 0.6668 - loss: 0.8207
# Epoch 10/100
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - accuracy: 0.6445 - loss: 0.8275
# Epoch 11/100
# ...

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2)

# Get validation accuracy
val_acc = history.history['val_accuracy'][-1]  # Last epoch's validation accuracy
print(f"Final Validation Accuracy: {val_acc:.4f}")
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9778 - loss: 0.0685 - val_accuracy: 0.9805 - val_loss: 0.0621
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9934 - loss: 0.0462 - val_accuracy: 0.9675 - val_loss: 0.0722
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.9902 - loss: 0.0517 - val_accuracy: 0.9805 - val_loss: 0.0657
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.9908 - loss: 0.0549 - val_accuracy: 0.9870 - val_loss: 0.0694
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.9913 - loss: 0.0510 - val_accuracy: 0.9870 - val_loss: 0.0677
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9944 - loss: 0.0437 - val_accuracy: 0.9870 - val_loss: 0.0664
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.9915 - loss: 0.0401 - val_accuracy: 0.9805 - val_loss: 0.0680
# Epoch 8/100
# ...

# %%
model.save("tic-tac-toe.keras")  # Saves in Keras format

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**
#
# 1. Handling Class Imbalance (Most Important)
#
#  Before: Dataset had 265 samples of class “0” and 501 samples of class “1” → The model was biased    toward predicting “1”.
#  What helped:
# 	•	Oversampling class “0” using RandomOverSampler()
# 	•	Balancing class weights (class_weight={0: 2.0, 1: 1.0})
#  This helped the model focus on class “0”, reducing misclassification.
#
#
# 2. Tuning Model Architecture
#
#  The original model had too many layers and was unstable.
#  What helped:
# 	•	Simplifying the model (fewer layers, removing unnecessary dropout)
# 	•	Using Batch Normalization to stabilize learning
# 	•	ReLU for hidden layers, Softmax for output
#  This improved learning efficiency and reduced loss.
#
#
# 3. Adjusting Learning Rate & Training Strategy
#
#  The model initially struggled because the learning rate was too high or too low at times.
#  What helped:
# 	•	Using Adam optimizer with a stable learning rate (0.001)
# 	•	Training on a small subset first before full training
# 	•	Early stopping to avoid overfitting
#  This ensured the model learned efficiently without unnecessary extra epochs.
#
#
# 4. Increasing Training Data
#
#  Instead of training on an imbalanced dataset, I resampled the data and trained with more balanced   inputs.
#  This prevented overfitting to one class and led to higher accuracy and lower loss.

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**
